# %%
import json
# información ingresada manual y directamente en python
data={"Tienda": [  
    {"Laptops":   
     [    {"Marca":"HP",
           "Cantidad":10 ,
           "Precio": "S/ 5,429.00"}
      ,    
           {"Marca":"Apple","Cantidad":20, "Precio":"S/ 8,962.00"},    
           {"Marca":"Lenovo","Cantidad":30 , "Precio":"S/ 7,929.00"} , 
            {"Marca":"DELL","Cantidad":40 ,"Precio":"S/ 6451.00"} ,
           {"Marca":"ASUS","Cantidad":35 , "Precio":"S/ 4,2648.00"},
      {"Marca":"ACER","Cantidad":42 , "Precio":"S/ 3,126.00"},
      {"Marca":"ADVANCE","Cantidad":35 , "Precio":"S/ 3,126.00"},
      {"Marca":"LG","Cantidad":28 , "Precio":"S/ 3,126.00"},
      {"Marca":"TOSHIBA","Cantidad":22 , "Precio":"S/ 3,126.00"},
      {"Marca":"MSI","Cantidad":65 , "Precio":"S/ 3,126.00"},
          {"Marca":"HUAWEI","Cantidad":39 , "Precio":"S/ 3,126.00"}]  
    },  
    {"celulares":   [    
        {"Marca":"APPLE","Cantidad":185, "Precio":"S/ 8,929.00"},   
        {"Marca":"ADVANCE","Cantidad":12 , "Precio":"S/ 8,929.00"},    
        {"Marca":"ALCATEL","Cantidad":25 ,"Precio":"S/ 8,929.00"},
        {"Marca":"ALPHA","Cantidad":16, "Precio":"S/ 8,929.00"},
        {"Marca":"ASUS","Cantidad":6, "Precio":"S/ 8,929.00"},
        {"Marca":"ALTRON","Cantidad":25, "Precio":"S/ 8,929.00"},
        {"Marca":"ENTEL","Cantidad":9, "Precio":"S/ 8,929.00"},
        {"Marca":"XIAOMI","Cantidad":2, "Precio":"S/ 8,929.00"},
        {"Marca":"HUAWEI","Cantidad":16, "Precio":"S/ 8,929.00"},
        {"Marca":"HTC","Cantidad":20, "Precio":"S/ 8,929.00"},
        {"Marca":"SANSUMG","Cantidad":46, "Precio":"S/ 8,929.00"},
        {"Marca":"CAT","Cantidad":35, "Precio":"S/ 8,929.00"},
        {"Marca":"BLU","Cantidad":45, "Precio":"S/ 8,929.00"},
        {"Marca":"NOKIA","Cantidad":51, "Precio":"S/ 8,929.00"},
        {"Marca":"REALME","Cantidad":2, "Precio":"S/ 8,929.00"},
        {"Marca":"ONEPLUS","Cantidad":8, "Precio":"S/ 8,929.00"},
        {"Marca":"SKY","Cantidad":7, "Precio":"S/ 8,929.00"}
           ]  },
    {"Smartwatch":   
     [    {"Marca":"LG","Cantidad":10 ,"Precio":"S/ 5,429.00"},    
           {"Marca":"APPLE","Cantidad":20, "Precio":"S/ 8,962.00"},    
           {"Marca":"XIAPMI","Cantidad":30 , "Precio":"S/ 7,929.00"} , 
            {"Marca":"AMAZFIT","Cantidad":40 ,"Precio":"S/ 6451.00"} ,
           {"Marca":"SAMSUNG","Cantidad":35 , "Precio":"S/ 4,2648.00"},
      {"Marca":"HANDS UP","Cantidad":42 , "Precio":"S/ 3,126.00"},
      {"Marca":"IWO","Cantidad":35 , "Precio":"S/ 3,126.00"},
      {"Marca":"REALME","Cantidad":28 , "Precio":"S/ 3,126.00"},
      {"Marca":"ROCKROSE","Cantidad":22 , "Precio":"S/ 3,126.00"}
      ]  
    },  
    {"Tablets":   
     [    {"Marca":"ALCATEL","Cantidad":10 ,"Precio":"S/ 5,429.00"},    
           {"Marca":"APPLE","Cantidad":20, "Precio":"S/ 8,962.00"},    
           {"Marca":"HUAWEI","Cantidad":30 , "Precio":"S/ 7,929.00" } , 
            {"Marca":"LENOVO","Cantidad":40 ,"Precio":"S/ 6451.00"} ,
           {"Marca":"SAMSUNG","Cantidad":35 , "Precio":"S/ 4,2648.00"},
      {"Marca":"WACOM","Cantidad":42 , "Precio":"S/ 3,126.00"},
      {"Marca":"BLACKLINE","Cantidad":35 , "Precio":"S/ 3,126.00"},
      {"Marca":"MOSHI","Cantidad":28 , "Precio":"S/ 3,126.00"}
      
      ]  
    } ,
    {"Cámaras":   
     [    {"Marca":"ALTRON","Cantidad":1 ,"Precio":"S/ 5,429.00"},    
           {"Marca":"CANON","Cantidad":20, "Precio":"S/ 8,962.00"},    
           {"Marca":"XIAOMI","Cantidad":8 , "Precio":"S/ 7,929.00" } , 
            {"Marca":"HANDS UP","Cantidad":16 ,"Precio":"S/ 6451.00"} ,
           {"Marca":"NIKON","Cantidad":12 , "Precio":"S/ 4,2648.00"},
      {"Marca":"DIGITAL CRAZY","Cantidad":12 , "Precio":"S/ 3,126.00"}
      ]}
]}

#encoded
data_string = json.dumps(data)

#Decoded
decoded = json.loads(data_string)

print(data)
#print(type(data))
#print(data.keys())

#print ("Tenemos "+str(decoded["Tienda"][0]["Laptops"][0]["Cantidad"])+" laptos Lenovo.")  #cantidad de laptops de la marca Lenovo
#print ("Tenemos "+str(decoded["Tienda"][1]["celulares"][0]["Cantidad"])+" celulares Apple.")  #cantidad de celulares de la marca Apple
#print(len(decoded["Tienda"][0]["Laptops"])) #cantidad de elementos almacenados en laptops
# Out:
# {'Tienda': [{'Laptops': [{'Marca': 'HP', 'Cantidad': 10, 'Precio': 'S/ 5,429.00'}, {'Marca': 'Apple', 'Cantidad': 20, 'Precio': 'S/ 8,962.00'}, {'Marca': 'Lenovo', 'Cantidad': 30, 'Precio': 'S/ 7,929.00'}, {'Marca': 'DELL', 'Cantidad': 40, 'Precio': 'S/ 6451.00'}, {'Marca': 'ASUS', 'Cantidad': 35, 'Precio': 'S/ 4,2648.00'}, {'Marca': 'ACER', 'Cantidad': 42, 'Precio': 'S/ 3,126.00'}, {'Marca': 'ADVANCE', 'Cantidad': 35, 'Precio': 'S/ 3,126.00'}, {'Marca': 'LG', 'Cantidad': 28, 'Precio': 'S/ 3,126.00'}, {'Marca': 'TOSHIBA', 'Cantidad': 22, 'Precio': 'S/ 3,126.00'}, {'Marca': 'MSI', 'Cantidad': 65, 'Precio': 'S/ 3,126.00'}, {'Marca': 'HUAWEI', 'Cantidad': 39, 'Precio': 'S/ 3,126.00'}]}, {'celulares': [{'Marca': 'APPLE', 'Cantidad': 185, 'Precio': 'S/ 8,929.00'}, {'Marca': 'ADVANCE', 'Cantidad': 12, 'Precio': 'S/ 8,929.00'}, {'Marca': 'ALCATEL', 'Cantidad': 25, 'Precio': 'S/ 8,929.00'}, {'Marca': 'ALPHA', 'Cantidad': 16, 'Precio': 'S/ 8,929.00'}, {'Marca': 'ASUS', 'Cantidad': 6, 'Precio'
# ...

# %%
import json

#leyendo el archivo Tienda.json
f= open(r"C:\Users\maryl\Music\códigos de clase lp2\TIENDA.json","r")
c= f.read()
#print(c)

#encode (a json)
data_string = json.dumps(c)
print(data_string)

#Decoded (a dictionaries de python)
js= json.loads(data_string)
#print(js)
#print(type(data))
#print(data.keys())

#cantidades totales de aparatos electrónicos
s=0
for i in range(len(decoded["Tienda"][0]["Laptops"])):            
    s=s+decoded["Tienda"][0]["Laptops"][i]["Cantidad"]
print("Tenemos",s," laptops de diferentes marcas")

s=0
for j in range(len(decoded["Tienda"][1]["celulares"])):            
    s=s+decoded["Tienda"][1]["celulares"][j]["Cantidad"]
print("Tenemos",s,"celulares de diferentes marcas")

s=0
for k in range(len(decoded["Tienda"][2]["Smartwatch"])):            
    s=s+decoded["Tienda"][2]["Smartwatch"][k]["Cantidad"]
print("Tenemos",s," smartwatches de diferentes marcas")

s=0
for l in range(len(decoded["Tienda"][3]["Tablets"])):            
    s=s+decoded["Tienda"][3]["Tablets"][l]["Cantidad"]
print("Tenemos",s," tablets de diferentes marcas")

s=0
for m in range(len(decoded["Tienda"][4]["Cámaras"])):            
    s=s+decoded["Tienda"][4]["Cámaras"][m]["Cantidad"]
print("Tenemos",s,"cámaras de diferentes marcas")
# Out:
# "{\"Tienda\": [  \n    {\"Laptops\":   \n     [    {\"Marca\":\"HP\",\n           \"Cantidad\":10 ,\n           \"Precio\": \"S/ 5,429.00\"}\n      ,    \n           {\"Marca\":\"Apple\",\"Cantidad\":20, \"Precio\":\"S/ 8,962.00\"},    \n           {\"Marca\":\"Lenovo\",\"Cantidad\":30 , \"Precio\":\"S/ 7,929.00\"} , \n            {\"Marca\":\"DELL\",\"Cantidad\":40 ,\"Precio\":\"S/ 6451.00\"} ,\n           {\"Marca\":\"ASUS\",\"Cantidad\":35 , \"Precio\":\"S/ 4,2648.00\"},\n      {\"Marca\":\"ACER\",\"Cantidad\":42 , \"Precio\":\"S/ 3,126.00\"},\n      {\"Marca\":\"ADVANCE\",\"Cantidad\":35 , \"Precio\":\"S/ 3,126.00\"},\n      {\"Marca\":\"LG\",\"Cantidad\":28 , \"Precio\":\"S/ 3,126.00\"},\n      {\"Marca\":\"TOSHIBA\",\"Cantidad\":22 , \"Precio\":\"S/ 3,126.00\"},\n      {\"Marca\":\"MSI\",\"Cantidad\":65 , \"Precio\":\"S/ 3,126.00\"},\n          {\"Marca\":\"HUAWEI\",\"Cantidad\":39 , \"Precio\":\"S/ 3,126.00\"}]  \n    },  \n    {\"celulares\":   [    \n        {\"Marca\":\"APP
# ...
