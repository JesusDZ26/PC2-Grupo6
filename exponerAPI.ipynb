# %%
from urllib.request import urlopen
#import numpy as np
#import matplotlib.pyplot as ptl
#import seaborn as sns
#from bs4 import BeautifulSoup as soup

# %%
import requests
import json

# %%
# Generamos la clave API
apikey="AIzaSyCJaWYymqfE-dLQKEDoA97T8tTqAKKkL6k"

# %%
# Colocamos el Localizador de Recursos Uniforme(URL)
url="https://www.youtube.com/"

# %%
uclient=urlopen(url)
responsehtml=uclient.read()
uclient.close()
data = responsehtml.decode()
data
# Out:
# '<!DOCTYPE html><html style="font-size: 10px;font-family: Roboto, Arial, sans-serif;" lang="es-419"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"/><script nonce="ym40cOtl1a913GLik0+8OQ">var ytcfg={d:function(){return window.yt&&yt.config_||ytcfg.data_||(ytcfg.data_={})},get:function(k,o){return k in ytcfg.d()?ytcfg.d()[k]:o},set:function(){var a=arguments;if(a.length>1)ytcfg.d()[a[0]]=a[1];else for(var k in a[0])ytcfg.d()[k]=a[0][k]}};\nwindow.ytcfg.set(\'EMERGENCY_BASE_URL\', \'\\/error_204?t\\x3djserror\\x26level\\x3dERROR\\x26client.name\\x3d1\\x26client.version\\x3d2.20210418.07.00\');</script><script nonce="ym40cOtl1a913GLik0+8OQ">(function(){window.yterr=window.yterr||true;window.unhandledErrorMessages={};window.unhandledErrorCount=0;\nwindow.onerror=function(msg,url,line,columnNumber,error){var err;if(error)err=error;else{err=new Error;err.stack="";err.message=msg;err.fileName=url;err.lineNumber=line;if(!isNaN(columnNumber))err["columnNumber"]=columnNumber}var mes
# ...

# %%
# Extraemos datos del sistema
responsehtml = requests.get('https://www.youtube.com/')
print(responsehtml)
# Out:
# <Response [200]>
